# %% [markdown]
# Recaman sequence for generative art
# https://simpleprogrammer.com/python-generative-art-math

# %% [raw]
# Definition
# The Recamán's sequence
#
# a(n) = 0 if n = 0
# a(n) = a(n-1) - n if a(n-1) - n  > 0 and not already in sequence
# else
# a(n) = a(n-1) + n
#
# The first terms of the sequence are:
#
# 0, 1, 3, 6, 2, 7, 13, 20, 12, 21, 11, 22, 10, 23, 9, 24, 8, 25, 43, 62, 42, 63, 41, 18, 42, 17, 43, 16, 44, 15, 45, 14, 46, 79, 113, 78, 114, 77, 39, 78, 38, 79, 37, 80, 36, 81, 35, 82, 34, 83, 33, 84, 32, 85, 31, 86, 30, 87, 29, 88, 28, 89, 27, 90, 26, 91, 157, 224, 156, 225, 155, ...

# %%
def recaman(n):
    rec = []
    rec.append(0)
    for i in range(1,n):
        x = rec[i-1] - i
        if x < 0 or x in rec:
            x = rec[i-1]+ i
        rec.append(x)
    return rec

# %%
recaman(20)
# Out:
# [0, 1, 3, 6, 2, 7, 13, 20, 12, 21, 11, 22, 10, 23, 9, 24, 8, 25, 43, 62]

# %%
import matplotlib.pyplot as plt
from random import random
from random import sample

# %%
c1 = [0 , 0, 0, 1]
x = recaman(100)
y = [ rec/max(x) for rec in x ]
plt.figure(figsize=(10,10))
for rad in y:
    a,b = 2*random(), 2*random()
    cen = tuple(sample(c1,2))
    circle=plt.Circle(cen,rad, color ='r', fill = 0 )
    plt.gcf().gca().add_artist(circle)

# %%
from matplotlib import patches

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

fg, ax = plt.subplots(1, 1)

pac = mpatches.Arc([0, 0], -5, -5, angle=45, theta1=180, theta2=0)
ax.add_patch(pac)

ax.axis([-5, 5, -5, 5])
ax.set_aspect("equal")
fg.canvas.draw()

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

fg, ax = plt.subplots(1, 1)
y = recaman(100)
x = [ r/max(y) for r in y ]

# %%
endpoints = [(a,b) for a,b in zip(x,x[1:])]
centrepoint = [(x+y)/2 for x,y in endpoints ]
heights = [(x-y)/2 for x,y in endpoints]

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
fg, ax = plt.subplots(1, 1)
for i,h in enumerate(heights):
    c = centrepoint[i]
    pac = mpatches.Arc((c,0), h, h, angle=0, theta1=0, theta2=180)
    ax.add_patch(pac)

ax.axis([0, 100, -20, 20])
ax.set_aspect("equal")
fg.canvas.draw()

# %%
x = recaman(100)
y = [ rec/max(x) for rec in x ]
plt.figure(figsize=(10,10))
for rad in y:

    circle=plt.Circle((0,0),rad, color ='r', fill = 0 )
    plt.gcf().gca().add_artist(circle)

# %%
random()
# Out:
# 0.8704750023677776

# %%
x = [1,2,3,4,5]
y = x[1:]
z = [(a,b) for a , b in zip(x,x[1:])]
z
# Out:
# [(1, 2), (2, 3), (3, 4), (4, 5)]

# %%
p = [(a-b)/ 2 for a,b in z]

# %%
import math

# %%
help(abs)
# Out:
# Help on built-in function abs in module builtins:
#
# abs(x, /)
#     Return the absolute value of the argument.

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-f0d9d180e18d> in <module>
# ----> 1 abs(p)
#
# TypeError: bad operand type for abs(): 'list'
